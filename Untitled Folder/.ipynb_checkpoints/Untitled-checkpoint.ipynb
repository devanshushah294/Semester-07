# %%
from PIL import Image

# %%
import numpy as np

# %%
image = Image.open("images.jpeg")

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>

# %%
image.show()

# %%
arr = np.array(image)

# %%
arr
# Out:
# array([[[ 50,  91, 171],
#         [ 50,  91, 171],
#         [ 49,  90, 170],
#         ...,
#         [ 14,  35,  82],
#         [ 13,  34,  81],
#         [ 13,  33,  83]],
#
#        [[ 50,  91, 171],
#         [ 49,  90, 170],
#         [ 48,  89, 169],
#         ...,
#         [ 13,  35,  82],
#         [ 13,  35,  82],
#         [ 13,  35,  84]],
#
#        [[ 49,  90, 169],
#         [ 49,  90, 169],
#         [ 48,  89, 168],
#         ...,
#         [ 13,  35,  82],
#         [ 13,  35,  82],
#         [ 16,  38,  87]],
#
#        ...,
#
#        [[198, 147,  94],
#         [189, 137,  87],
#         [177, 127,  78],
#         ...,
#         [ 42, 128,  65],
#         [ 64, 150,  87],
#         [ 41, 105,  55]],
#
#        [[189, 138,  85],
#         [177, 125,  75],
#         [164, 114,  63],
#         ...,
#         [ 71, 157,  94],
#         [ 80, 166, 103],
#         [ 48, 112,  62]],
#
#        [[159, 108,  61],
#         [169, 121,  75],
#         [156, 109,  65],
# ...

# %%
arr.shape
# Out:
# (225, 225, 3)

# %%
new_array = arr[::-1]

# %%
image_02 = Image.fromarray(new_array)

# %%
image_02
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
new_array2 = arr[::,::-1]

# %%
image_03 = Image.fromarray(new_array2)

# %%
image_03
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
new_array3 = arr[100::,::]

# %%
image_04 = Image.fromarray(new_array3)

# %%
image_04
# Out:
# <PIL.Image.Image image mode=RGB size=225x125>
